# %% [markdown]
# # ch05.10. 사이킷런 실습 - 비선형회귀분석
#
# ---
# * 날짜: 2022.05.24
# * 이름: 윤태우
#
# ## 학습내용
#     - 다항식을 이용한 회귀 분석을 진행한다.
#     - 랜덤 포레스트를 이용해 비선형 회귀를 진행한다.
#     - 앙상블 학습에 대해 이해한다.

# %% [markdown]
# ```
# import numpy as np
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# ```

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/MyDrive/script')
from Scores import *

# %% [markdown]
# ## **선형 회귀 모델을 다항 회귀로 변환**
# ---

# %% [markdown]
# ### **| 간단한 데이터에 대한 다항 회귀**

# %% [markdown]
# #### **데이터**
# ```
# X = np.array([258.0, 270.0, 294.0,
#               320.0, 342.0, 368.0,
#               396.0, 446.0, 480.0, 586.0]).reshape(-1, 1)
#
# y = np.array([236.4, 234.4, 252.8,
#               298.6, 314.2, 342.2,
#               360.8, 368.0, 391.2,
#               390.8])
# ```

# %% [markdown]
# * 데이터 생성

# %%
X = np.array([258.0, 270.0, 294.0, 
              320.0, 342.0, 368.0, 
              396.0, 446.0, 480.0, 586.0]).reshape(-1, 1)

y = np.array([236.4, 234.4, 252.8, 
              298.6, 314.2, 342.2, 
              360.8, 368.0, 391.2,
              390.8])
X.shape, y.shape
# Out:
# ((10, 1), (10,))

# %% [markdown]
# * 시각화

# %%
plt.scatter(X, y)

# %% [markdown]
# #### **선형 특성 학습**

# %%
from sklearn.linear_model import *
lr1 = LinearRegression()
lr1.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# #### **이차항 특성 학습**

# %%
# polynomial : 다항식
from sklearn.preprocessing import PolynomialFeatures
quad = PolynomialFeatures(degree=2)
X_quad = quad.fit_transform(X)
X.shape, X_quad.shape
# Out:
# ((10, 1), (10, 3))

# %% [markdown]
# * X 데이터 변환

# %%
quad.get_feature_names()
pd.DataFrame(X_quad, columns=quad.get_feature_names())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#      1     x0      x0^2
# 0  1.0  258.0   66564.0
# 1  1.0  270.0   72900.0
# 2  1.0  294.0   86436.0
# 3  1.0  320.0  102400.0
# 4  1.0  342.0  116964.0
# 5  1.0  368.0  135424.0
# 6  1.0  396.0  156816.0
# 7  1.0  446.0  198916.0
# 8  1.0  480.0  230400.0
# 9  1.0  586.0  343396.0

# %% [markdown]
# * 학습

# %%
lr2 = LinearRegression()
lr2.fit(X_quad, y)
# Out:
# LinearRegression()

# %% [markdown]
# #### **테스트셋 성능 비교**

# %%
y_pred1 = lr1.predict(X)
y_pred2 = lr2.predict(X_quad)

l1_scores = regression_scores(y, y_pred1)
l2_scores = regression_scores(y, y_pred2)
pd.DataFrame([l1_scores,l2_scores], index=['linear', 'quadratic'])
# Out:
#               MSE    RMSE    MAE   NMAE   MAPE     R2
# linear     569.78  23.870  0.070  0.069  7.035  0.832
# quadratic   61.33   7.831  0.022  0.020  2.213  0.982

# %% [markdown]
# #### **그래프 시각화**

# %%
X_every = np.arange(250, 600, 0.1).reshape(-1,1)

plt.scatter(X, y, label='trainset', c='k')
plt.plot(X_every, lr1.predict(X_every), label='linear')
plt.plot(X_every, lr2.predict(quad.fit_transform(X_every)), label='quadratic')
plt.legend()
plt.show()

# %% [markdown]
# ### **| 주택 데이터를 이용한 비선형 회귀 분석**

# %% [markdown]
# #### **주택 데이터셋**
#
# [https://archive.ics.uci.edu/ml/datasets/Housing](https://archive.ics.uci.edu/ml/datasets/Housing)
#
#
# <pre>
# 01. CRIM     도시의 인당 범죄율
# 02. ZN       2만 5,0000평방 피트가 넘는 주택 비율
# 03. INDUS    도시에서 소매 업종이 아닌 지역 비율
# 04. CHAS     찰스 강 인접 여부(강 주변=1, 그외=0)
# 05. NOX      일산화질소 농도(10ppm당)
# 06. RM       주택의 평균 방 개수
# 07. AGE      1940년 이전에 지어진 자가 주택 비율
# 08. DIS      다섯 개의 보스턴 고용 센터까지 가중치가 적용된 거리
# 09. RAD      방사형으로 뻗은 고속도로까지 접근성 지수
# 10. TAX      10만 달러당 재산세율
# 11. PTRATIO  도시의 학생-교사 비율
# 12. B        1000(Bk - 0.63)^2 도시의 아프리카계 미국인 비율
# 13. LSTAT    저소득층 비율
# 14. MEDV     자가 주택의 중간가격 (단위 $1000s)
# </pre>

# %% [markdown]
# * 데이터 불러오기

# %%
from Data_loader import *

X_train, X_test, y_train, y_test = housing_loader(['LSTAT'])
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (506, 14)
# ((404, 1), (102, 1), (404,), (102,))

# %% [markdown]
# * 시각화

# %%
def draw_data():
  plt.scatter(X_train, y_train, label='Trainset', color='lightblue')
  plt.scatter(X_test, y_test, label='Testset', color='lightgreen')
  plt.xlabel('% lower status of the population [LSTAT]')
  plt.ylabel('Price in $1000s [MEDV]')
  plt.legend()
draw_data()

# %% [markdown]
# #### **선형 모델 학습**

# %%
lr1 = LinearRegression()
lr1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### **이차 다항 모델 학습**

# %%
lr2 = LinearRegression()
quad =  PolynomialFeatures(degree=2)
X_quad = quad.fit_transform(X_train)
lr2.fit(X_quad, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### **삼차 다항 모델 학습**

# %%
lr3 = LinearRegression()
cubic = PolynomialFeatures(degree=3)
X_cubic = cubic.fit_transform(X_train)
lr3.fit(X_cubic, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### **테스트셋 성능 비교**

# %%
y_pred1 = lr1.predict(X_test)
y_pred2 = lr2.predict(quad.fit_transform(X_test))
y_pred3 = lr3.predict(cubic.fit_transform(X_test))

l1_scores = regression_scores(y_test, y_pred1)
l2_scores = regression_scores(y_test, y_pred2)
l3_scores = regression_scores(y_test, y_pred3)

df_score = pd.DataFrame([l1_scores,l2_scores,l3_scores], index=['linear', 'quadratic', 'cubic'])
df_score.style.background_gradient()
# Out:
# <style type="text/css">
# #T_f1faf_row0_col0, #T_f1faf_row0_col1, #T_f1faf_row0_col3, #T_f1faf_row1_col2, #T_f1faf_row1_col4, #T_f1faf_row2_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f1faf_row0_col2, #T_f1faf_row0_col4 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_f1faf_row0_col5, #T_f1faf_row2_col0, #T_f1faf_row2_col1, #T_f1faf_row2_col2, #T_f1faf_row2_col3, #T_f1faf_row2_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_f1faf_row1_col0 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_f1faf_row1_col1 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_f1faf_row1_col3 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_f1faf_row1_col5 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f1faf_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MSE</th>
#       <th class="col_heading level0 col1" >RMSE</th>
#       <th class="col_heading level0 col2" >MAE</th>
#       <th class="col_heading level0 col3" >NMAE</th>
#       <th class="col_heading level0 col4" >MAPE</th>
#       <th class="col_heading level0 col5" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1faf_level0_row0" class="row_heading level0 row0" >linear</th>
#       <td id="T_f1faf_row0_col0" class="data row0 col0" >0.463000</td>
#       <td id="T_f1faf_row0_col1" class="data row0 col1" >0.680000</td>
#       <td id="T_f1faf_row0_col2" class="data row0 col2" >6.718000</td>
#       <td id="T_f1faf_row0_col3" class="data row0 col3" >0.721000</td>
#       <td id="T_f1faf_row0_col4" class="data row0 col4" >671.832000</td>
#       <td id="T_f1faf_row0_col5" class="data row0 col5" >0.537000</td>
#     </tr>
#     <tr>
#       <th id="T_f1faf_level0_row1" class="row_heading level0 row1" >quadratic</th>
#       <td id="T_f1faf_row1_col0" class="data row1 col0" >0.343000</td>
#       <td id="T_f1faf_row1_col1" class="data row1 col1" >0.586000</td>
#       <td id="T_f1faf_row1_col2" class="data row1 col2" >7.132000</td>
#       <td id="T_f1faf_row1_col3" class="data row1 col3" >0.640000</td>
#       <td id="T_f1faf_row1_col4" class="data row1 col4" >713.233000</td>
#       <td id="T_f1faf_row1_col5" class="data row1 col5" >0.657000</td>
#     </tr>
#     <tr>
#       <th id="T_f1faf_level0_row2" class="row_heading level0 row2" >cubic</th>
#       <td id="T_f1faf_row2_col0" class="data row2 col0" >0.315000</td>
#       <td id="T_f1faf_row2_col1" class="data row2 col1" >0.562000</td>
#       <td id="T_f1faf_row2_col2" class="data row2 col2" >6.529000</td>
#       <td id="T_f1faf_row2_col3" class="data row2 col3" >0.606000</td>
#       <td id="T_f1faf_row2_col4" class="data row2 col4" >652.893000</td>
#       <td id="T_f1faf_row2_col5" class="data row2 col5" >0.685000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **그래프 시각화**

# %%
draw_data()

X_every = np.arange(-2, 3, 0.1).reshape(-1,1)
plt.plot(X_every, lr1.predict(X_every), 
         label='Linear',
         linewidth=3, linestyle=':')
plt.plot(X_every, lr2.predict(quad.fit_transform(X_every)), 
         label='Quadratic',
         linewidth=3)
plt.plot(X_every, lr3.predict(cubic.fit_transform(X_every)), 
         label='Cubic',
         linewidth=3, linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# ## **랜덤 포레스트를 사용하여 비선형 관계 다루기**
# ---
#
# ![](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2F96F6N%2FbtqwVglgV2S%2FYTCytd7Z2egbnbJM29MJv1%2Fimg.png)
#
# *출처:  ratsgo's blog

# %% [markdown]
# ### **| 결정트리 회귀**

# %% [markdown]
# #### **모델 학습**

# %%
from sklearn.tree import DecisionTreeRegressor

tree = DecisionTreeRegressor(max_depth=3, random_state=1)
tree.fit(X_train, y_train)
y_pred = tree.predict(X_test)

# %% [markdown]
# #### **테스트셋 성능비교**

# %%
df_score.loc['tree']=regression_scores(y_test, y_pred)
df_score.style.background_gradient(cmap='Greens_r')
# Out:
# <style type="text/css">
# #T_e5247_row0_col0, #T_e5247_row0_col1, #T_e5247_row0_col3, #T_e5247_row1_col2, #T_e5247_row1_col4, #T_e5247_row3_col5 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_e5247_row0_col2, #T_e5247_row0_col4 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_e5247_row0_col5, #T_e5247_row3_col0, #T_e5247_row3_col1, #T_e5247_row3_col2, #T_e5247_row3_col3, #T_e5247_row3_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_e5247_row1_col0 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_e5247_row1_col1 {
#   background-color: #248c46;
#   color: #f1f1f1;
# }
# #T_e5247_row1_col3 {
#   background-color: #58b668;
#   color: #f1f1f1;
# }
# #T_e5247_row1_col5 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_e5247_row2_col0 {
#   background-color: #005522;
#   color: #f1f1f1;
# }
# #T_e5247_row2_col1 {
#   background-color: #005924;
#   color: #f1f1f1;
# }
# #T_e5247_row2_col2, #T_e5247_row2_col4 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_e5247_row2_col3 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_e5247_row2_col5 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# </style>
# <table id="T_e5247_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MSE</th>
#       <th class="col_heading level0 col1" >RMSE</th>
#       <th class="col_heading level0 col2" >MAE</th>
#       <th class="col_heading level0 col3" >NMAE</th>
#       <th class="col_heading level0 col4" >MAPE</th>
#       <th class="col_heading level0 col5" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5247_level0_row0" class="row_heading level0 row0" >linear</th>
#       <td id="T_e5247_row0_col0" class="data row0 col0" >0.463000</td>
#       <td id="T_e5247_row0_col1" class="data row0 col1" >0.680000</td>
#       <td id="T_e5247_row0_col2" class="data row0 col2" >6.718000</td>
#       <td id="T_e5247_row0_col3" class="data row0 col3" >0.721000</td>
#       <td id="T_e5247_row0_col4" class="data row0 col4" >671.832000</td>
#       <td id="T_e5247_row0_col5" class="data row0 col5" >0.537000</td>
#     </tr>
#     <tr>
#       <th id="T_e5247_level0_row1" class="row_heading level0 row1" >quadratic</th>
#       <td id="T_e5247_row1_col0" class="data row1 col0" >0.343000</td>
#       <td id="T_e5247_row1_col1" class="data row1 col1" >0.586000</td>
#       <td id="T_e5247_row1_col2" class="data row1 col2" >7.132000</td>
#       <td id="T_e5247_row1_col3" class="data row1 col3" >0.640000</td>
#       <td id="T_e5247_row1_col4" class="data row1 col4" >713.233000</td>
#       <td id="T_e5247_row1_col5" class="data row1 col5" >0.657000</td>
#     </tr>
#     <tr>
#       <th id="T_e5247_level0_row2" class="row_heading level0 row2" >cubic</th>
#       <td id="T_e5247_row2_col0" class="data row2 col0" >0.315000</td>
#       <td id="T_e5247_row2_col1" class="data row2 col1" >0.562000</td>
#       <td id="T_e5247_row2_col2" class="data row2 col2" >6.529000</td>
#       <td id="T_e5247_row2_col3" class="data row2 col3" >0.606000</td>
#       <td id="T_e5247_row2_col4" class="data row2 col4" >652.893000</td>
#       <td id="T_e5247_row2_col5" class="data row2 col5" >0.685000</td>
#     </tr>
#     <tr>
#       <th id="T_e5247_level0_row3" class="row_heading level0 row3" >tree</th>
#       <td id="T_e5247_row3_col0" class="data row3 col0" >0.307000</td>
#       <td id="T_e5247_row3_col1" class="data row3 col1" >0.554000</td>
#       <td id="T_e5247_row3_col2" class="data row3 col2" >5.807000</td>
#       <td id="T_e5247_row3_col3" class="data row3 col3" >0.578000</td>
#       <td id="T_e5247_row3_col4" class="data row3 col4" >580.727000</td>
#       <td id="T_e5247_row3_col5" class="data row3 col5" >0.693000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **그래프 시각화**

# %%
draw_data()
plt.plot(X_every, tree.predict(X_every), lw=3)    
plt.show()

# %% [markdown]
# ### **| 랜덤 포레스트 회귀 (Random Forest Regressor)**

# %% [markdown]
# #### **모델 학습**

# %%
from sklearn.ensemble import RandomForestRegressor
# ensemble : 앙상블
forest = RandomForestRegressor(random_state=1)
forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=1)

# %% [markdown]
# #### **테스트셋 성능 비교**

# %%
y_pred = forest.predict(X_test)
df_score.loc['forest']=regression_scores(y_test, y_pred)
df_score.style.background_gradient(cmap='Greens_r')
# Out:
# <style type="text/css">
# #T_fb6ef_row0_col0, #T_fb6ef_row0_col1, #T_fb6ef_row0_col3, #T_fb6ef_row1_col2, #T_fb6ef_row1_col4, #T_fb6ef_row3_col5 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T
#       <td id="T_fb6ef_row4_col0" class="data row4 col0" >0.439000</td>
#       <td id="T_fb6ef_row4_col1" class="data row4 col1" >0.663000</td>
#       <td id="T_fb6ef_row4_col2" class="data row4 col2" >4.781000</td>
#       <td id="T_fb6ef_row4_col3" class="data row4 col3" >0.685000</td>
#       <td id="T_fb6ef_row4_col4" class="data row4 col4" >478.131000</td>
#       <td id="T_fb6ef_row4_col5" class="data row4 col5" >0.561000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **그래프 시각화**

# %%
draw_data()
plt.plot(X_every, forest.predict(X_every), lw=3)    
plt.show()

# %% [markdown]
# ### **| 엑스트라 트리 (Extra Tree Regressor)**

# %% [markdown]
# #### **모델 학습**

# %%
from sklearn.ensemble import ExtraTreesRegressor

et = ExtraTreesRegressor(random_state=1)
et.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor(random_state=1)

# %% [markdown]
# #### **테스트셋 성능 비교**

# %%
y_pred = et.predict(X_test)
df_score.loc['et']=regression_scores(y_test, y_pred)
df_score.style.background_gradient(cmap='Greens_r')
# Out:
# <style type="text/css">
# #T_83940_row0_col0, #T_83940_row0_col1, #T_83940_row0_col3, #T_83940_row1_col2, #T_83940_row1_col4, #T_83940_row3_col5 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_83940_row0_col2, #T_83940_row0_col4 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_83940_row0_col5, #T_83940_row3_col0, #T_83940_row3_col1, #T_83940_row3_col3, #T_83940_row5_col2, #T_83940_row5_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_83940_row1_col0 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_83940_row1_col1 {
#   background-color: #248c46;
#   color: #f1f1f1;
# }
# #T_83940_row1_col3 {
#   background-color: #58b668;
#   color: #f1f1f1;
# }
# #T_83940_row1_col5 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_83940_row2_col0 {
#   background-color: #005522;
#   color: #f1f1f1;
# }
# #T_83940_row2_col1 {
#   background-color: #005924;
#   color: #f1f1f1;
# }
# #T_83940_row2_col2, #T_83940_row2_col4 {
#   background-color: #d2edcc;
#   color: #000000;
# }
# #T_83940_row2_col3 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_83940_row2_col5 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_83940_row3_col2, #T_83940_row3_col4 {
#   background-color: #87cd86;
#   color: #000000;
# }
# #T_83940_row4_col0 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_83940_row4_col1 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_83940_row4_col2, #T_83940_row4_col4 {
#   background-color: #16803c;
#   color: #f1f1f1;
# }
# #T_83940_row4_col3 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_83940_row4_col5 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_83940_row5_col0 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_83940_row5_col1 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_83940_row5_col3 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_83940_row5_col5 {
#   background-color: #0a7633;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_83940_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MSE</th>
#       <th class="col_heading level0 col1" >RMSE</th>
#       <th class="col_heading level0 col2" >MAE</th>
#       <th class="col_heading level0 col3" >NMAE</th>
#       <th class="col_heading level0 col4" >MAPE</th>
#       <th class="col_heading level0 col5" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83940_level0_row0" class="row_heading level0 row0" >linear</th>
#       <td id="T_83940_row0_col0" class="data row0 col0" >0.463000</td>
#       <td id="T_83940_row0_col1" class="data row0 col1" >0.680000</td>
#       <td id="T_83940_row0_col2" class="data row0 col2" >6.718000</td>
#       <td id="T_83940_row0_col3" class="data row0 col3" >0.721000</td>
#       <td id="T_83940_row0_col4" class="data row0 col4" >671.832000</td>
#       <td id="T_83940_row0_col5" class="data row0 col5" >0.537000</td>
#     </tr>
#     <tr>
#       <th id="T_83940_level0_row1" class="row_heading level0 row1" >quadratic</th>
#       <td id="T_83940_row1_col0" class="data row1 col0" >0.343000</td>
#       <td id="T_83940_row1_col1" class="data row1 col1" >0.586000</td>
#       <td id="T_83940_row1_col2" class="data row1 col2" >7.132000</td>
#       <td id="T_83940_row1_col3" class="data row1 col3" >0.640000</td>
#       <td id="T_83940_row1_col4" class="data row1 col4" >713.233000</td>
#       <td id="T_83940_row1_col5" class="data row1 col5" >0.657000</td>
#     </tr>
#     <tr>
#       <th id="T_83940_level0_row2" class="row_heading level0 row2" >cubic</th>
#       <td id="T_83940_row2_col0" class="data row2 col0" >0.315000</td>
#       <td id="T_83940_row2_col1" class="data row2 col1" >0.562000</td>
#       <td id="T_83940_row2_col2" class="data row2 col2" >6.529000</td>
#       <td id="T_83940_row2_col3" class="data row2 col3" >0.606000</td>
#       <td id="T_83940_row2_col4" class="data row2 col4" >652.893000</td>
#       <td id="T_83940_row2_col5" class="data row2 col5" >0.685000</td>
#     </tr>
#     <tr>
#       <th id="T_83940_level0_row3" class="row_heading level0 row3" >tree</th>
#       <td id="T_83940_row3_col0" class="data row3 col0" >0.307000</td>
#       <td id="T_83940_row3_col1" class="data row3 col1" >0.554000</td>
#       <td id="T_83940_row3_col2" class="data row3 col2" >5.807000</td>
#       <td id="T_83940_row3_col3" class="data row3 col3" >0.578000</td>
#       <td id="T_83940_row3_col4" class="data row3 col4" >580.727000</td>
#       <td id="T_83940_row3_col5" class="data row3 col5" >0.693000</td>
#     </tr>
#     <tr>
#       <th id="T_83940_level0_row4" class="row_heading level0 row4" >forest</th>
#       <td id="T_83940_row4_col0" class="data row4 col0" >0.439000</td>
#       <td id="T_83940_row4_col1" class="data row4 col1" >0.663000</td>
#       <td id="T_83940_row4_col2" class="data row4 col2" >4.781000</td>
#       <td id="T_83940_row4_col3" class="data row4 col3" >0.685000</td>
#       <td id="T_83940_row4_col4" class="data row4 col4" >478.131000</td>
#       <td id="T_83940_row4_col5" class="data row4 col5" >0.561000</td>
#     </tr>
#     <tr>
#       <th id="T_83940_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_83940_row5_col0" class="data row5 col0" >0.438000</td>
#       <td id="T_83940_row5_col1" class="data row5 col1" >0.662000</td>
#       <td id="T_83940_row5_col2" class="data row5 col2" >4.178000</td>
#       <td id="T_83940_row5_col3" class="data row5 col3" >0.686000</td>
#       <td id="T_83940_row5_col4" class="data row5 col4" >417.761000</td>
#       <td id="T_83940_row5_col5" class="data row5 col5" >0.562000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **그래프 시각화**

# %%
draw_data()
plt.plot(X_every, et.predict(X_every), lw=3)    
plt.show()

# %% [markdown]
# ### **| Gradient Boosting Regressor**

# %% [markdown]
# #### **모델 학습**

# %%
from sklearn.ensemble import GradientBoostingRegressor

gb = GradientBoostingRegressor(random_state=1)
gb.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=1)

# %% [markdown]
# #### **테스트셋 성능 비교**

# %%
y_pred = gb.predict(X_test)
df_score.loc['gb']=regression_scores(y_test, y_pred)
df_score.style.background_gradient(cmap='Greens_r')
# Out:
# <style type="text/css">
# #T_201b9_row0_col0, #T_201b9_row0_col1, #T_201b9_row0_col3, #T_201b9_row1_col2, #T_201b9_row1_col4, #T_201b9_row3_col5 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_201b9_row0_col2, #T_201b9_row0_col4, #T_201b9_row4_col1 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_201b9_row0_col5, #T_201b9_row3_col0, #T_201b9_row3_col1, #T_201b9_row3_col3, #T_201b9_row6_col2, #T_201b9_row6_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_201b9_row1_col0 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_201b9_row1_col1 {
#   background-color: #248c46;
#   color: #f1f1f1;
# }
# #T_201b9_row1_col3 {
#   background-color: #58b668;
#   color: #f1f1f1;
# }
# #T_201b9_row1_col5 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_201b9_row2_col0 {
#   background-color: #005522;
#   color: #f1f1f1;
# }
# #T_201b9_row2_col1 {
#   background-color: #005924;
#   color: #f1f1f1;
# }
# #T_201b9_row2_col2, #T_201b9_row2_col4 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T
level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_201b9_row5_col0" class="data row5 col0" >0.438000</td>
#       <td id="T_201b9_row5_col1" class="data row5 col1" >0.662000</td>
#       <td id="T_201b9_row5_col2" class="data row5 col2" >4.178000</td>
#       <td id="T_201b9_row5_col3" class="data row5 col3" >0.686000</td>
#       <td id="T_201b9_row5_col4" class="data row5 col4" >417.761000</td>
#       <td id="T_201b9_row5_col5" class="data row5 col5" >0.562000</td>
#     </tr>
#     <tr>
#       <th id="T_201b9_level0_row6" class="row_heading level0 row6" >gb</th>
#       <td id="T_201b9_row6_col0" class="data row6 col0" >0.336000</td>
#       <td id="T_201b9_row6_col1" class="data row6 col1" >0.580000</td>
#       <td id="T_201b9_row6_col2" class="data row6 col2" >4.102000</td>
#       <td id="T_201b9_row6_col3" class="data row6 col3" >0.588000</td>
#       <td id="T_201b9_row6_col4" class="data row6 col4" >410.178000</td>
#       <td id="T_201b9_row6_col5" class="data row6 col5" >0.664000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **그래프 시각화**

# %%
draw_data()
plt.plot(X_every, gb.predict(X_every), lw=3)    
plt.show()

# %% [markdown]
# ### **| XGBoost Regressor**

# %% [markdown]
# #### **모델 학습**

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor(random_state=1)
xgb.fit(X_train, y_train)
# Out:
# [01:36:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(random_state=1)

# %% [markdown]
# #### **테스트셋 성능 비교**

# %%
y_pred = xgb.predict(X_test)
df_score.loc['xgb']=regression_scores(y_test, y_pred)
df_score.style.background_gradient(cmap='Greens_r')
# Out:
# <style type="text/css">
# #T_25710_row0_col0, #T_25710_row0_col1, #T_25710_row0_col3, #T_25710_row1_col2, #T_25710_row1_col4, #T_25710_row3_col5 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_25710_row0_col2, #T_25710_row0_col4 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_25710_row0_col5, #T_25710_row3_col0, #T_25710_row3_col1, #T_25710_row7_col2, #T_25710_row7_col3, #T_25710_row7_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_25710_row1_col0 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_25710_row1_col1 {
#   background-color: #248c46;
#   color: #f1f1f1;
# }
# #T_25710_row1_col3 {
#   background-color: #5eb96b;
#   color: #f1f1f1;
# }
# #T_25710_row1_col5 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_25710_row2_col0 {
#   background-color: #005522;
#   color: #f1f1f1;
# }
# #T_25710_row2_col1 {
#   background-color: #005924;
#   color: #f1f1f1;
# }
# #T_25710_row2_col2, #T_25710_row2_col4 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_25710_row2_col3 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_25710_row2_col5 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_25710_row3_col2, #T_25710_row3_col4 {
#   background-color: #90d18d;
#   color: #000000;
# }
# #T_25710_row3_col3 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_25710_row4_col0 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_25710_row4_col1 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_25710_row4_col2, #T_25710_row4_col4 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_25710_row4_col3 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_25710_row4_col5 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_25710_row5_col0 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_25710_row5_col1 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_25710_row5_col2, #T_25710_row5_col4 {
#   background-color: #005622;
#   color: #f1f1f1;
# }
# #T_25710_row5_col3 {
#   background-color: #cbeac4;
#   color: #000000;
# }
# #T_25710_row5_col5 {
#   background-color: #0a7633;
#   color: #f1f1f1;
# }
# #T_25710_row6_col0 {
#   background-color: #117b38;
#   color: #f1f1f1;
# }
# #T_25710_row6_col1 {
#   background-color: #16803c;
#   color: #f1f1f1;
# }
# #T_25710_row6_col2, #T_25710_row6_col4 {
#   background-color: #004e1f;
#   color: #f1f1f1;
# }
# #T_25710_row6_col3, #T_25710_row7_col0 {
#   background-color: #006328;
#   color: #f1f1f1;
# }
# #T_25710_row6_col5 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_25710_row7_col1 {
#   background-color: #006529;
#   color: #f1f1f1;
# }
# #T_25710_row7_col5 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# </style>
# <table id="T_25710_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MSE</th>
#       <th class="col_heading level0 col1" >RMSE</th>
#       <th class="col_heading level0 col2" >MAE</th>
#       <th class="col_heading level0 col3" >NMAE</th>
#       <th class="col_heading level0 col4" >MAPE</th>
#       <th class="col_heading level0 col5" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_
#       <td id="T_25710_row6_col3" class="data row6 col3" >0.588000</td>
#       <td id="T_25710_row6_col4" class="data row6 col4" >410.178000</td>
#       <td id="T_25710_row6_col5" class="data row6 col5" >0.664000</td>
#     </tr>
#     <tr>
#       <th id="T_25710_level0_row7" class="row_heading level0 row7" >xgb</th>
#       <td id="T_25710_row7_col0" class="data row7 col0" >0.322000</td>
#       <td id="T_25710_row7_col1" class="data row7 col1" >0.567000</td>
#       <td id="T_25710_row7_col2" class="data row7 col2" >4.003000</td>
#       <td id="T_25710_row7_col3" class="data row7 col3" >0.574000</td>
#       <td id="T_25710_row7_col4" class="data row7 col4" >400.252000</td>
#       <td id="T_25710_row7_col5" class="data row7 col5" >0.678000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **그래프 시각화**

# %%
draw_data()
plt.plot(X_every, xgb.predict(X_every), lw=3)    
plt.show()

# %% [markdown]
# ## **과제1: 주택 데이터셋 다중 회귀 분석**
# ---
#
# * 주택 데이터셋의 X의 모든 속성을 이용해 y를 예측합니다.
# * 지난시간과 이번시간에 배운 회귀 분석 모델을 모두 사용해보고, 성능을 비교해 봅니다.
# * 단, 다항회귀는 사용하지 마세요.
# * 사용 모델 :
# ```
# 'linear', 'ridge', 'lasso', 'elastic', 'bayes_ridge', 'tree', 'forest', 'et', 'gb', 'xgb'
# ```

# %% [markdown]
# #### **데이터 불러오기**

# %%
X_train, X_test, y_train, y_test = housing_loader()
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (506, 14)
# ((404, 13), (102, 13), (404,), (102,))

# %% [markdown]
# * 분석 예시

# %%
linear = LinearRegression()
ridge = Ridge(alpha=0.1, random_state=1)
lasso = Lasso(alpha=0.1, random_state=1)
elastic = ElasticNet(alpha=0.1, random_state=1)
bayes_ridge = BayesianRidge()
tree = DecisionTreeRegressor(max_depth=3, random_state=1)
forest = RandomForestRegressor(random_state=1)
et = ExtraTreesRegressor(random_state=1)
gb = GradientBoostingRegressor(random_state=1)
xgb = XGBRegressor(random_state=1)

df_score = pd.DataFrame()
plt.figure(figsize=(20,9))
for idx, model in enumerate(['linear', 'ridge', 'lasso', 'elastic', 'bayes_ridge', 
                             'tree', 'forest', 'et', 'gb', 'xgb']):
  # 모델별 학습 및 예측
  eval(model).fit(X_train, y_train)
  y_pred = eval(model).predict(X_test)
  
  # 실제-예측 산점도
  plt.subplot(2,5,idx+1)
  plt.title(model)
  plt.scatter(y_test, y_pred, marker='.')
  plt.plot([-2,3],[-2,3], c='r')
  plt.xlabel('y_true')
  plt.ylabel('y_pred')
  
  # 성능 평가
  df_score = pd.concat([df_score, pd.DataFrame(regression_scores(y_test, y_pred) ,index=[model]) ])

plt.show()
df_score.style.background_gradient(cmap='Greens_r')
# Out:
# [01:48:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# <style type="text/css">
# #T_ed857_row0_col0, #T_ed857_row1_col0 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_ed857_row0_col1, #T_ed857_row1_col1 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_ed857_row0_col2, #T_ed857_row0_col4, #T_ed857_row1_col2, #T_ed857_row1_col4 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_ed857_row0_col3 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_ed857_row0_col5, #T_ed857_row1_col5 {
#   background-color: #48ae60;
#   color: #f1f1f1;
# }
# #T_ed857_row1_col3 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T
#       <td id="T_ed857_row3_col2" class="data row3 col2" >5.837000</td>
#       <td id="T_ed857_row3_col3" class="data row3 col3" >0.573000</td>
#       <td id="T_ed857_row3_col4" class="data row3 col4" >583.659000</td>
#       <td id="T_ed857_row3_col5" class="data row3 col5" >0.720000</td>
#     </tr>
#     <tr>
#       <th id="T_ed857_level0_row4" class="row_heading level0 row4" >bayes_ridge</th>
#       <td id="T_ed857_row4_col0" class="data row4 col0" >0.220000</td>
#       <td id="T_ed857_row4_col1" class="data row4 col1" >0.469000</td>
#       <td id="T_ed857_row4_col2" class="data row4 col2" >5.904000</td>
#       <td id="T_ed857_row4_col3" class="data row4 col3" >0.516000</td>
#       <td id="T_ed857_row4_col4" class="data row4 col4" >590.402000</td>
#       <td id="T_ed857_row4_col5" class="data row4 col5" >0.780000</td>
#     </tr>
#     <tr>
#       <th id="T_ed857_level0_row5" class="row_heading level0 row5" >tree</th>
#       <td id="T_ed857_row5_col0" class="data row5 col0" >0.218000</td>
#       <td id="T_ed857_row5_col1" class="data row5 col1" >0.467000</td>
#       <td id="T_ed857_row5_col2" class="data row5 col2" >6.582000</td>
#       <td id="T_ed857_row5_col3" class="data row5 col3" >0.543000</td>
#       <td id="T_ed857_row5_col4" class="data row5 col4" >658.168000</td>
#       <td id="T_ed857_row5_col5" class="data row5 col5" >0.782000</td>
#     </tr>
#     <tr>
#       <th id="T_ed857_level0_row6" class="row_heading level0 row6" >forest</th>
#       <td id="T_ed857_row6_col0" class="data row6 col0" >0.095000</td>
#       <td id="T_ed857_row6_col1" class="data row6 col1" >0.308000</td>
#       <td id="T_ed857_row6_col2" class="data row6 col2" >2.836000</td>
#       <td id="T_ed857_row6_col3" class="data row6 col3" >0.336000</td>
#       <td id="T_ed857_row6_col4" class="data row6 col4" >283.617000</td>
#       <td id="T_ed857_row6_col5" class="data row6 col5" >0.905000</td>
#     </tr>
#     <tr>
#       <th id="T_ed857_level0_row7" class="row_heading level0 row7" >et</th>
#       <td id="T_ed857_row7_col0" class="data row7 col0" >0.079000</td>
#       <td id="T_ed857_row7_col1" class="data row7 col1" >0.282000</td>
#       <td id="T_ed857_row7_col2" class="data row7 col2" >2.389000</td>
#       <td id="T_ed857_row7_col3" class="data row7 col3" >0.297000</td>
#       <td id="T_ed857_row7_col4" class="data row7 col4" >238.864000</td>
#       <td id="T_ed857_row7_col5" class="data row7 col5" >0.921000</td>
#     </tr>
#     <tr>
#       <th id="T_ed857_level0_row8" class="row_heading level0 row8" >gb</th>
#       <td id="T_ed857_row8_col0" class="data row8 col0" >0.105000</td>
#       <td id="T_ed857_row8_col1" class="data row8 col1" >0.324000</td>
#       <td id="T_ed857_row8_col2" class="data row8 col2" >2.012000</td>
#       <td id="T_ed857_row8_col3" class="data row8 col3" >

# %% [markdown]
# ## **과제2: 해외 축구 선수 이적료 예측 미션**
# ---
#
# * https://dacon.io/competitions/open/235538/overview/description
# * 수업 시간에 배운 내용들을 적용하여 이적료 예측을 진행하고 리더보드에 결과를 제출합니다.
